# %%
### My goal is to develop an algoritm that can recommend Anime Movies based on User Ratings (animelist) and watching status(completed)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read data
anime = pd.read_csv('anime.csv')
anime.head(5)
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
anime.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
anime.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
anime.columns
# Out:
# Index(['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members'], dtype='object')

# %%
anime.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
anime[anime['anime_id']==1]
# Out:
#     anime_id          name                                            genre  \
# 22         1  Cowboy Bebop  Action, Adventure, Comedy, Drama, Sci-Fi, Space
#
#    type episodes  rating  members
# 22   TV       26    8.82   486824

# %%
anime[anime['rating']>9].count()
# Out:
# anime_id    18
# name        18
# genre       18
# type        18
# episodes    18
# rating      18
# members     18
# dtype: int64

# %%
anime[anime['rating']>9].sort_index(ascending=True)
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# 5         32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6         11061                             Hunter x Hunter (2011)
# 7           820                               Ginga Eiyuu Densetsu
# 8         15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9         15417                           Gintama&#039;: Enchousen
# 10         4181                               Clannad: After Story
# 11        28851                                     Koe no Katachi
# 12          918                                            Gintama
# ...

# %%
anime.hist(color="g", figsize=(15,10), bins=10, alpha=0.6)
# Out:
# /home/ipek/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([[<AxesSubplot:title={'center':'anime_id'}>,
#         <AxesSubplot:title={'center':'rating'}>],
#        [<AxesSubplot:title={'center':'members'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
anime_tv = anime[anime['type']=='TV']
anime_tv.head()
# Out:
#    anime_id                                               name  \
# 1      5114                   Fullmetal Alchemist: Brotherhood
# 2     28977                                           Gintama°
# 3      9253                                        Steins;Gate
# 4      9969                                      Gintama&#039;
# 5     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
#
#                                                genre type episodes  rating  \
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...   TV       51    9.25
# 3                                   Sci-Fi, Thriller   TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...   TV       51    9.16
# 5             Comedy, Drama, School, Shounen, Sports   TV       10    9.15
#
#    members
# 1   793665
# 2   114262
# 3   673572
# 4   151266
# 5    93351

# %%
# What sort of correlation exists between genre and rating?

corr = anime.corr()
corr
# Out:
#           anime_id    rating   members
# anime_id  1.000000 -0.284625 -0.080071
# rating   -0.284625  1.000000  0.387979
# members  -0.080071  0.387979  1.000000

# %%
anime_corr = anime.corr().abs().unstack().sort_values(kind="quicksort", ascending=False).reset_index()
anime_corr.rename(columns={"level_0": "Feature 1", "level_1": "Feature 2", 0: 'Correlation Coefficient'}, inplace=True)
anime_corr[anime_corr['Feature 1'] == 'genre']
# Out:
# Empty DataFrame
# Columns: [Feature 1, Feature 2, Correlation Coefficient]
# Index: []
